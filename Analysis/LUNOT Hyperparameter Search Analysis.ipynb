# %%
import pandas as pd
import plotly.express as px

# %%
round_1_results = pd.read_excel('LUNOT Hyperparameter Search.xlsx', sheet_name='Round 1', index_col=0)
px.scatter(round_1_results, x='lr', log_x=True, y='n_neighbours', color='max_val_score')

# %%
px.scatter(round_1_results[round_1_results['n_neighbours']>5], x='lr', log_x=True, y='n_neighbours', color='max_val_score')

# %%
round_2_results = pd.read_excel('LUNOT Hyperparameter Search.xlsx', sheet_name='Round 2', index_col=0)
px.scatter(round_2_results, x='lr', log_x=True, y='n_neighbours', color='max_val_score')

# %% [markdown]
# 50 neighbours at 0.02 learning rate

# %%
round_3_results = pd.read_excel('LUNOT Hyperparameter Search.xlsx', sheet_name='Round 3', index_col=0)
px.scatter(round_3_results, x='batch_size', y='layer_size', color='max_val_score')

# %%
px.scatter(round_3_results[round_3_results['max_val_score']>0.73], x='batch_size', y='layer_size', color='max_val_score')

# %% [markdown]
# layer size of 150 and batch size of 300 (model performance is not very sensitive to these hyperparameters though)

# %%
round_4_results = pd.read_excel('LUNOT Hyperparameter Search.xlsx', sheet_name='Round 4', index_col=0)
px.scatter(round_4_results, x='lr_schedule_k', y='layer_count', color='max_val_score')

# %%
px.scatter(round_4_results[round_4_results['layer_count']>2], x='lr_schedule_k', y='layer_count', color='max_val_score')

# %% [markdown]
# 4 layers with a 0.2 learning rate schedule multiplicative constant (again hardly affects performance)
